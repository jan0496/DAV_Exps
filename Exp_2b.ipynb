# %%
import pandas as pd

# Load dataset into a DataFrame
df = pd.read_csv('data.csv')

# %%
# Display first and last few rows 
print("First 5 rows:\n", df.head()) 
print("Last 5 rows:\n", df.tail())
# Out:
# First 5 rows:
#     existing_column1  existing_column  another_column category_column  \
# 0                 5             10.0              80               A
# 1                 8             15.0             120               B
# 2                12             20.0              60               A
# 3                 3             25.0              90               C
# 4                 7             18.0              45               B
#
#    numeric_column
# 0            95.0
# 1            88.0
# 2            76.0
# 3            82.0
# 4            91.0
# Last 5 rows:
#      existing_column1  existing_column  another_column category_column  \
# 10                 6             12.0              40               B
# 11                14             35.0              98               A
# 12                13             27.0             102               C
# 13                 2             14.0              65               B
# 14                16             40.0              88               A
#
#     numeric_column
# 10            70.0
# 11            99.0
# 12            81.0
# 13            74.0
# 14            97.0

# %%
# Check data types and general info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   existing_column1  15 non-null     int64
#  1   existing_column   14 non-null     float64
#  2   another_column    15 non-null     int64
#  3   category_column   15 non-null     object
#  4   numeric_column    14 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 732.0+ bytes

# %%
# Summary statistics
print("Summary statistics:\n", df.describe())
# Out:
# Summary statistics:
#         existing_column1  existing_column  another_column  numeric_column
# count         15.000000        14.000000       15.000000       14.000000
# mean           9.000000        22.285714       80.533333       84.071429
# std            4.472136         8.939356       23.630690       10.186449
# min            2.000000        10.000000       40.000000       67.000000
# 25%            5.500000        15.250000       62.500000       76.750000
# 50%            9.000000        21.000000       85.000000       83.500000
# 75%           12.500000        27.750000       96.500000       92.500000
# max           16.000000        40.000000      120.000000       99.000000

# %%
# Handle missing values 
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
# Create a new column
df['new_column'] = df['existing_column'] * 2

# %%
# Create a Series and perform operations 
series = df['existing_column']
print("Series addition:", series + 10)
# Out:
# Series addition: 0     20.000000
# 1     25.000000
# 2     30.000000
# 3     35.000000
# 4     28.000000
# 5     40.000000
# 6     32.000000
# 7     32.285714
# 8     26.000000
# 9     38.000000
# 10    22.000000
# 11    45.000000
# 12    37.000000
# 13    24.000000
# 14    50.000000
# Name: existing_column, dtype: float64

# %%
# Filter rows based on conditions
filtered_df = df[(df['existing_column'] > 50) & (df['another_column'] < 100)] 
print("Filtered DataFrame:\n", filtered_df)
# Out:
# Filtered DataFrame:
#  Empty DataFrame
# Columns: [existing_column1, existing_column, another_column, category_column, numeric_column, new_column]
# Index: []

# %%
# Grouping and aggregation
grouped = df.groupby('category_column')['numeric_column'].mean() 
print("Grouped mean:\n", grouped)
# Out:
# Grouped mean:
#  category_column
# A    89.345238
# B    80.400000
# C    80.750000
# Name: numeric_column, dtype: float64

# %%
# Sorting
df_sorted = df.sort_values(by='numeric_column', ascending=False) 
print("Sorted DataFrame:\n", df_sorted)
# Out:
# Sorted DataFrame:
#      existing_column1  existing_column  another_column category_column  \
# 11                14        35.000000              98               A
# 14                16        40.000000              88               A
# 0                  5        10.000000              80               A
# 9                  4        28.000000              55               C
# 4                  7        18.000000              45               B
# 1                  8        15.000000             120               B
# 5                 10        30.000000              75               A
# 8                 11        16.000000              85               A
# 3                  3        25.000000              90               C
# 12                13        27.000000             102               C
# 7                  9        22.285714              95               B
# 2                 12        20.000000              60               A
# 13                 2        14.000000              65               B
# 10                 6        12.000000              40               B
# 6                 15        22.000000             110               C
#
#     numeric_column  new_column
# 11       99.000000   70.000000
# 14       97.000000   80.000000
# 0        95.000000   20.000000
# 9        93.000000   56.000000
# 4        91.000000   36.000000
# 1        88.000000   30.000000
# 5        85.000000   60.000000
# 8        84.071429   32.000000
# 3        82.000000   50.000000
# 12       81.000000   54.000000
# 7        79.000000   44.571429
# 2        76.000000   40.000000
# 13       74.000000   28.000000
# 10       70.000000   24.000000
# 6        67.000000   44.000000

# %%
# Boolean masking
masked_df = df[df['numeric_column'] > df['numeric_column'].median()]
print("Masked DataFrame:\n", masked_df)
# Out:
# Masked DataFrame:
#      existing_column1  existing_column  another_column category_column  \
# 0                  5             10.0              80               A
# 1                  8             15.0             120               B
# 4                  7             18.0              45               B
# 5                 10             30.0              75               A
# 9                  4             28.0              55               C
# 11                14             35.0              98               A
# 14                16             40.0              88               A
#
#     numeric_column  new_column
# 0             95.0        20.0
# 1             88.0        30.0
# 4             91.0        36.0
# 5             85.0        60.0
# 9             93.0        56.0
# 11            99.0        70.0
# 14            97.0        80.0

# %%
# Remove duplicates and drop missing values 
df.drop_duplicates(inplace=True) 
df.dropna(inplace=True)

# %%
# Create a new DataFrame with selected columns
subset_df = df[['existing_column1', 'numeric_column']]

# %%
# Compute summary statistics
print("Total sum:", df['numeric_column'].sum()) 
print("Mean:", df['numeric_column'].mean()) 
print("Standard Deviation:", df['numeric_column'].std())
# Out:
# Total sum: 1261.0714285714284
# Mean: 84.07142857142857
# Standard Deviation: 9.815907539108471
